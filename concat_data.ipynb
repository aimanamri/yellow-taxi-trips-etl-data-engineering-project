# %% [markdown]
# # DATASET

# %% [markdown]
# ## Concatenate all downloaded Parquet files by years

# %%
import glob
import pandas as pd

# %%
def create_df_year(year):
    dfs = []
    # Read parquet files from directory /data/{year} 
    for fin in glob.glob(f'./data/{year}/*.parquet'):
      dfs.append(pd.read_parquet(fin))
    df = pd.concat(dfs)
    return df

def save_as_parquet_compressed(df,name = 'df'):
        return df.to_parquet(f'{name}.parquet.gzip',
              compression='gzip')

# %%
df_2022 = create_df_year(2022)

# %%
df_2022
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 3399544         2  2022-12-31 23:46:00   2023-01-01 00:11:00              NaN
# 3399545         2  2022-12-31 23:13:24   2022-12-31 23:29:08              NaN
# 3399546         2  2022-12-31 23:00:49   2022-12-31 23:26:57              NaN
# 3399547         1  2022-12-31 23:02:50   2022-12-31 23:16:05              NaN
# 3399548         2  2022-12-31 23:00:15   2022-12-31 23:22:56              NaN
#
# ...

# %%
df_2021 = create_df_year(2021)

# %%
df_2021
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1               1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2               1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3               1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4               2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ...           ...                  ...                   ...              ...
# 3214364         2  2021-12-31 23:18:02   2021-12-31 23:32:19              NaN
# 3214365         2  2021-12-31 23:46:00   2022-01-01 00:07:00              NaN
# 3214366         2  2021-12-31 23:46:00   2022-01-01 00:04:00              NaN
# 3214367         2  2021-12-31 23:53:00   2022-01-01 00:02:00              NaN
# 3214368         2  2021-12-31 23:19:28   2021-12-31 23:26:30              NaN
#
# ...

# %%
df_2020 = create_df_year(2020)

# %%
df_2020
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1               1  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2               1  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3               1  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4               2  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
# ...           ...                  ...                   ...              ...
# 1461893         2  2020-12-31 23:44:35   2021-01-01 00:01:22              NaN
# 1461894         2  2020-12-31 23:41:36   2020-12-31 23:50:32              NaN
# 1461895         2  2020-12-31 23:01:17   2020-12-31 23:40:37              NaN
# 1461896         2  2020-12-31 23:31:29   2020-12-31 23:44:22              NaN
# 1461897         2  2020-12-31 23:12:48   2020-12-31 23:24:51              NaN
#
# ...

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24649092 entries, 0 to 1461897
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            object
# dtypes: datetime64[us](2), float64(11), int64(4), object(2)
# memory usage: 3.7+ GB

# %% [markdown]
# <hr>
#
# **SUMMARY NO. OF ROWS:** <br>
# 1. `df_2022` : 39,656,098 rows <br>
# 2. `df_2021` : 30,904,308 rows <br>
# 3. `df_2020` : 24,649,092 rows

# %% [markdown]
# ##  Get the first N rows randomly from each month
# `*.parquet.gzip` files are still too large to upload into Github and take too much storage/bandwidth even with Git LFS. (about 1.5GB+)
#
# Hence, reducing the file size is the best solution by filtering the rows for this side project use. Here, we will use first `20,000` rows randomly from each month

# %% [markdown]
# ### 2022 Dataset CSV and Parquet format

# %%
df = pd.read_parquet('2022.parquet.gzip').dropna(subset=['passenger_count', 'RatecodeID'], how='all')
df = df.groupby([df['tpep_pickup_datetime'].dt.month]).apply(lambda x: x.sample(20000)).reset_index(drop=True).sort_values(by='tpep_pickup_datetime').reset_index(drop=True)
df
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              2  2002-10-23 16:21:59   2002-10-23 16:22:08              3.0
# 1              2  2002-10-27 02:35:45   2002-10-27 03:03:00              1.0
# 2              2  2022-01-01 00:06:58   2022-01-01 00:15:52              2.0
# 3              2  2022-01-01 00:08:27   2022-01-01 00:21:40              1.0
# 4              2  2022-01-01 00:09:02   2022-01-01 00:30:55              1.0
# ...          ...                  ...                   ...              ...
# 239995         2  2022-12-31 23:46:30   2022-12-31 23:49:45              1.0
# 239996         2  2022-12-31 23:53:50   2023-01-01 00:03:14              1.0
# 239997         2  2022-12-31 23:56:28   2023-01-01 00:12:48              1.0
# 239998         2  2022-12-31 23:56:45   2023-01-01 00:11:34              1.0
# 239999         2  2022-12-31 23:58:06   2023-01-01 00:02:08              1.0
#
# ...

# %%
# Check the count of rows if 10,000 rows were exactly selected or not.
df['tpep_pickup_datetime'].groupby([df['tpep_pickup_datetime'].dt.month]).agg('count')
# Out:
# tpep_pickup_datetime
# 1     20000
# 2     20000
# 3     20000
# 4     20000
# 5     20000
# 6     20000
# 7     20000
# 8     20000
# 9     20000
# 10    20000
# 11    20000
# 12    20000
# Name: tpep_pickup_datetime, dtype: int64

# %%
df.to_csv('data_2022.csv', index=False)
df.to_parquet('data_2022.parquet', index=False)

# %% [markdown]
# ### 2021 Dataset CSV and Parquet format

# %%
df1 = pd.read_parquet('2021.parquet.gzip').dropna(subset=['passenger_count', 'RatecodeID'], how='all')
df1 = df1.groupby([df1['tpep_pickup_datetime'].dt.month]).apply(lambda x: x.sample(20000)).reset_index(drop=True).sort_values(by='tpep_pickup_datetime').reset_index(drop=True)
df1
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              2  2008-12-31 22:59:12   2008-12-31 23:08:12              1.0
# 1              2  2009-01-01 00:03:00   2009-01-01 00:07:23              1.0
# 2              2  2009-01-01 00:03:10   2009-01-01 17:12:05              1.0
# 3              2  2009-01-01 00:04:14   2009-01-01 00:18:10              1.0
# 4              2  2009-01-01 00:10:40   2009-01-02 00:06:30              1.0
# ...          ...                  ...                   ...              ...
# 239995         2  2021-12-31 23:39:29   2021-12-31 23:47:58              1.0
# 239996         2  2021-12-31 23:48:24   2022-01-01 00:07:40              1.0
# 239997         2  2021-12-31 23:49:06   2021-12-31 23:50:21              1.0
# 239998         2  2021-12-31 23:50:15   2021-12-31 23:58:52              1.0
# 239999         2  2022-01-17 12:51:59   2022-01-17 12:59:05              4.0
#
# ...

# %%
# Check the count of rows if 10,000 rows were exactly  selected or not.
df1['tpep_pickup_datetime'].groupby([df1['tpep_pickup_datetime'].dt.month]).agg('count')
# Out:
# tpep_pickup_datetime
# 1     20000
# 2     20000
# 3     20000
# 4     20000
# 5     20000
# 6     20000
# 7     20000
# 8     20000
# 9     20000
# 10    20000
# 11    20000
# 12    20000
# Name: tpep_pickup_datetime, dtype: int64

# %%
df1.to_csv('data_2021.csv', index=False)
df1.to_parquet('data_2021.parquet', index=False)

# %% [markdown]
# ### 2020 Dataset CSV and Parquet format

# %%
df2 = pd.read_parquet('2020.parquet.gzip').dropna(subset=['passenger_count', 'RatecodeID'], how='all')
df2 = df2.groupby([df2['tpep_pickup_datetime'].dt.month]).apply(lambda x: x.sample(20000)).reset_index(drop=True).sort_values(by='tpep_pickup_datetime').reset_index(drop=True)
df2
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              2  2008-12-31 23:05:27   2009-01-01 12:13:35              1.0
# 1              2  2009-01-01 23:51:06   2009-01-02 00:02:23              2.0
# 2              2  2019-12-31 18:21:19   2020-01-01 17:57:53              1.0
# 3              2  2019-12-31 19:13:46   2019-12-31 19:23:49              1.0
# 4              2  2019-12-31 23:59:33   2020-01-01 00:03:25              2.0
# ...          ...                  ...                   ...              ...
# 239995         1  2020-12-31 23:42:21   2021-01-01 00:01:51              1.0
# 239996         2  2020-12-31 23:42:59   2020-12-31 23:54:22              1.0
# 239997         2  2020-12-31 23:45:42   2020-12-31 23:56:25              2.0
# 239998         1  2020-12-31 23:50:34   2020-12-31 23:53:46              1.0
# 239999         1  2020-12-31 23:52:35   2021-01-01 00:12:35              1.0
#
# ...

# %%
# Check the count of rows if 10,000 rows were exactly  selected or not.
df2['tpep_pickup_datetime'].groupby([df2['tpep_pickup_datetime'].dt.month]).agg('count')
# Out:
# tpep_pickup_datetime
# 1     20000
# 2     20000
# 3     20000
# 4     20000
# 5     20000
# 6     20000
# 7     20000
# 8     20000
# 9     20000
# 10    20000
# 11    20000
# 12    20000
# Name: tpep_pickup_datetime, dtype: int64

# %%
df2.to_csv('data_2020.csv', index=False)
df2.to_parquet('data_2020.parquet', index=False)

# %% [markdown]
# <hr>
#
# **SUMMARY CSV FILE SIZE:** <br>
# 1. `data_2022.csv` : 24 MB <br>
# 2. `data_2021.csv` : 24 MB <br>
# 3. `data_2020.csv` : 23 MB<br>
#
# **SUMMARY PARQUET FILE SIZE:** <br>
# 1. `data_2022.parquet` : 6 MB <br>
# 2. `data_2021.parquet` : 5 MB <br>
# 3. `data_2020.parquet` : 5 MB

# %% [markdown]
# ## Miscs

# %%
#Reading data using pandas read_parquet()
pd.read_parquet('data_2020.parquet')
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              2  2008-12-31 23:05:27   2009-01-01 12:13:35              1.0
# 1              2  2009-01-01 23:51:06   2009-01-02 00:02:23              2.0
# 2              2  2019-12-31 18:21:19   2020-01-01 17:57:53              1.0
# 3              2  2019-12-31 19:13:46   2019-12-31 19:23:49              1.0
# 4              2  2019-12-31 23:59:33   2020-01-01 00:03:25              2.0
# ...          ...                  ...                   ...              ...
# 239995         1  2020-12-31 23:42:21   2021-01-01 00:01:51              1.0
# 239996         2  2020-12-31 23:42:59   2020-12-31 23:54:22              1.0
# 239997         2  2020-12-31 23:45:42   2020-12-31 23:56:25              2.0
# 239998         1  2020-12-31 23:50:34   2020-12-31 23:53:46              1.0
# 239999         1  2020-12-31 23:52:35   2021-01-01 00:12:35              1.0
#
# ...

# %%
# 2019 and 2018 are not used for this project
# df_2019 = create_df_year(2019)
# df_2018 = create_df_year(2018)
